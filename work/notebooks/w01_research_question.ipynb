# %% [markdown]
# <a href="https://colab.research.google.com/github/areebazia-lsh/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the Content Refresh Prioritization lane. My goal is to identify which content pages should be refreshed first based on their performance. This lane is useful because updating the right pages can improve content quality and help editors focus on pages that need attention the most. I believe this problem is suitable for machine learning because many different factors influence page performance, making it difficult to create a simple manual rule.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Decision, Action and Cost
#
# This project helps content editors decide which pages should be reviewed and updated first.
#
# The output will be a ranked list of pages that are most likely to need refreshing.
#
# If the recommendation is wrong, editors may spend time updating pages that do not need changes while ignoring pages that actually require attention.
#
# Machine learning can help by analyzing multiple signals together instead of relying on a single rule.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 pages** and **44 columns**, providing a good amount of information for analysis.
#
# The dataset contains pages with different trend directions. There are **16,262 declining pages**, **5,962 stable pages**, **4,388 growing pages**, **2,236 new pages**, and **1,152 flat pages**.
#
# The average CTR in the dataset is **0.511**, showing that user engagement varies across different content pages. These numbers suggest that prioritizing which pages to refresh is a meaningful problem to explore.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Total Columns:", len(df.columns))
print(df["trend_direction"].value_counts())
print("Average CTR:", round(df["ctr"].mean(), 3))
# Out:
# Total Pages: 30000
# Total Columns: 44
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project provides observed and data-driven recommendations based on the available dataset.
#
# The results should be treated as decision-support rather than proof.
#
# The model cannot predict Google's algorithm or guarantee future rankings.
#
# Any findings will be described as measured, observed, or directional instead of causal.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
