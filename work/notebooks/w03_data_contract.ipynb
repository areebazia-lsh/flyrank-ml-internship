# %% [markdown]
# <a href="https://colab.research.google.com/github/areebazia-lsh/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ### Unit of Analysis
#
# One row represents the daily performance of one content page for one client on one report date.
#
# ### Time Window
#
# For this project, I will use a mid-panel month (March 2026) to explore the data and build features. I avoid using the final month because it should remain an honest evaluation period.

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'flyrank-ml-internship', 'sample_data']

# %%
import os
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship

# %%
import os

os.chdir("/content/flyrank-ml-internship")
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship

# %%
# !pip install -q -r requirements.txt

# %%
# !git clone https://github.com/areebazia-lsh/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 123 (delta 38), reused 78 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 8.95 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ### Features
# - impressions_90d
# - ctr
# - avg_position
# - engagement_rate
# - content_age_days
#
# ### Label
# - trend_direction (used to identify declining content pages)
#
# ### Context
# - client_id
# - content_id
# - report_date
# - content_type
#
# ### Excluded
# - trend_pct (derived from the label and causes data leakage)
# - trend_direction as a feature (it is the target, not an input)

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Rows:", len(df))
print("Total Columns:", len(df.columns))

print("\nMissing Values:")
print(df[[
    "impressions_90d",
    "ctr",
    "avg_position",
    "engagement_rate",
    "content_age_days"
]].isnull().sum())
# Out:
# Total Rows: 30000
# Total Columns: 44
#
# Missing Values:
# impressions_90d     0
# ctr                 0
# avg_position        0
# engagement_rate     0
# content_age_days    0
# dtype: int64

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
selected = [
    "impressions_90d",
    "ctr",
    "avg_position",
    "engagement_rate",
    "content_age_days"
]

print(df[selected].isnull().sum())
# Out:
# impressions_90d     0
# ctr                 0
# avg_position        0
# engagement_rate     0
# content_age_days    0
# dtype: int64

# %%
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())
# Out:
# Rows: 30000
# Columns: 44
#
# Trend Direction Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %%
print("Total Rows:", len(df))
print("\nSample Data:")
df[["content_id", "client_id"]].head()
# Out:
# Total Rows: 30000
#
# Sample Data:
#              content_id          client_id
# 0  content_304f48230142  client_f369cb89fc
# 1  content_a1fb4e703a9e  client_4e07408562
# 2  content_9aa793d4d895  client_7f2253d7e2
# 3  content_331d6c4de07b  client_19581e27de
# 4  content_d99b7a2d90ca  client_3fdba35f04

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ### Data Limits
#
# - This starter dataset is anonymized, so I cannot identify real clients or websites.
# - The data shows observed relationships only and cannot prove causation.
# - The dataset represents a fixed time period and may not reflect future search behavior.
# - Label-derived fields such as trend_pct should not be used as features because they cause data leakage.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
